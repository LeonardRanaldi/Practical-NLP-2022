# %% [markdown]
# # 🐸 KERMIT
# This is a trial version of KERMIT on Google Colab
#
# The potential of the system will be shown during the notebook.

# %% [markdown]
# **Link** https://virtual.2020.emnlp.org/paper_main.1210.html

# %%
#Clone repository and install libraries 
# !rm -r KERMIT
# !git clone https://github.com/ART-Group-it/KERMIT
# Out:
# Cloning into 'KERMIT'...
# remote: Enumerating objects: 653, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 653 (delta 163), reused 62 (delta 41), pack-reused 419
# Receiving objects: 100% (653/653), 14.66 MiB | 23.27 MiB/s, done.
# Resolving deltas: 100% (335/335), done.

# %%
# !git clone https://github.com/ariana2011/shared_weights
# Out:
# Cloning into 'shared_weights'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 0), reused 3 (delta 0), pack-reused 3
# Unpacking objects: 100% (6/6), 7.26 MiB | 6.88 MiB/s, done.

# %%
#required version
# !pip install transformers==2.6.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==2.6.0
#   Downloading transformers-2.6.0-py3-none-any.whl (540 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.9/540.9 KB 5.5 MB/s eta 0:00:00
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 23.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers==2.6.0) (3.9.0)
# Collecting tokenizers==0.5.2
#   Downloading tokenizers-0.5.2-cp38-cp38-manylinux1_x86_64.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 32.8 MB/s eta 0:00:00
# Collecting boto3
#   Downloading boto3-1.26.51-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 KB 1.2 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers==2.6.0) (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from transformers==2.6.0) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers==2.6.0) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers==2.6.0) (2022.6.2)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 6.4 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.51
#   Downloading botocore-1.29.51-py3-none-any.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 62.8 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==2.6.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==2.6.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==2.6.0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==2.6.0) (4.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==2.6.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==2.6.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==2.6.0) (1.2.0)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore<1.30.0,>=1.29.51->boto3->transformers==2.6.0) (2.8.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=3ece0bf1e8af52eeb8c516fdbf6ad3fc8636538db337668cc496af7bea03f354
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# Installing collected packages: tokenizers, sentencepiece, urllib3, sacremoses, jmespath, botocore, s3transfer, boto3, transformers
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed boto3-1.26.51 botocore-1.29.51 jmespath-1.0.1 s3transfer-0.6.0 sacremoses-0.0.53 sentencepiece-0.1.97 tokenizers-0.5.2 transformers-2.6.0 urllib3-1.26.14

# %%
#download and install parser
# !pip install stanfordcorenlp
# !wget http://nlp.stanford.edu/software/stanford-corenlp-full-2018-10-05.zip
# !unzip stanford-corenlp-full-2018-10-05.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stanfordcorenlp
#   Downloading stanfordcorenlp-3.9.1.1-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from stanfordcorenlp) (2.25.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from stanfordcorenlp) (5.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->stanfordcorenlp) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->stanfordcorenlp) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->stanfordcorenlp) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->stanfordcorenlp) (2.10)
# Installing collected packages: stanfordcorenlp
# Successfully installed stanfordcorenlp-3.9.1.1
# --2023-01-18 14:25:31--  http://nlp.stanford.edu/software/stanford-corenlp-full-2018-10-05.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/software/stanford-corenlp-full-2018-10-05.zip [following]
# --2023-01-18 14:25:31--  https://nlp.stanford.edu/software/stanford-corenlp-full-2018-10-05.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://downloads.cs.stanford.edu/nlp/software/stanford-corenlp-full-2018-10-05.zip [following]
# --2023-01-18 14:25:31--  https://downloads.cs.stanford.edu/nlp/software/stanford-corenlp-full-2018-10-05.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 393239982 (375M) [application/zip]
# Saving to: ‘stanford-corenlp-full-2018-10-05.zip’
#
# stanford-corenlp-fu 100%[===================>] 375.02M  4.98MB/s    in 70s
#
# 2023-01-18 14:26:42 (5.37 MB/s) - ‘stanford-corenlp-full-2018-10-05.zip’ saved [393239982/393239982]
#
# Archive:  stanford-corenlp-full-2018-10-05.zip
#    creating: stanford-corenlp-full-2018-10-05/
#   inflating: stanford-corenlp-full-2018-10-05/jaxb-core-2.3.0.1-sources.jar
#   inflating: stanford-corenlp-full-2018-10-05/xom-1.2.10-src.jar
#   inflating: stanford-corenlp-full-2018-10-05/CoreNLP-to-HTML.xsl
#   inflating: stanford-corenlp-full-2018-10-05/README.txt
#   inflating: stanford-corenlp-full-2018-10-05/jollyday-0.4.9-sources.jar
#   inflating: stanford-corenlp-full-2018-10-05/LIBRARY-LICENSES
#    creating: stanford-corenlp-full-2018-10-05/sutime/
#   inflating: stanford-corenlp-full-2018-10-05/sutime/british.sutime.txt
#   inflating: stanford-corenlp-full-2018-10-05/sutime/defs.sutime.txt
#   inflating: stanford-corenlp-full-2018-10-05/sutime/spanish.sutime.txt
#   inflating: stanford-corenlp-full-2018-10-05/sutime/english.sutime.txt
#   inflating: stanford-corenlp-full-2018-10-05/sutime/english.holidays.sutime.txt
#  extracting: stanford-corenlp-full-2018-10-05/ejml-0.23-src.zip
#   inflating: stanford-corenlp-full-2018-10-05/input.txt.xml
#   inflating: stanford-corenlp-full-2018-10-05/build.xml
#   inflating: stanford-corenlp-full-2018-10-05/pom.xml
#   inflating: stanford-corenlp-full-2018-10-05/stanford-corenlp-3.9.2-javadoc.jar
#    creating: stanford-corenlp-full-2018-10-05/tokensregex/
#   inflating: stanford-corenlp-full-2018-10-05/tokensregex/color.input.txt
#   inflating: stanford-corenlp-full-2018-10-05/tokensregex/retokenize.txt
#   inflating: stanford-corenlp-full-2018-10-05/tokensregex/color.properties
#   inflating: stanford-corenlp-full-2018-10-05/tokensregex/color.rules.txt
#   inflating: stanford-corenlp-full-2018-10-05/javax.json-api-1.0-sources.jar
#   inflating: stanford-corenlp-full-2018-10-05/jaxb-api-2.4.0-b180830.0359-sources.jar
#   inflating: stanford-corenlp-full-2018-10-05/stanford-corenlp-3.9.2-models.jar
#   inflating: stanford-corenlp-full-2018-10-05/protobuf.jar
#   inflating: stanford-corenlp-full-2018-10-05/javax.activation-api-1.2.0.jar
#   inflating: stanford-corenlp-full-2018-10-05/StanfordDependenciesManual.pdf
#    creating: stanford-corenlp-full-2018-10-05/patterns/
#   inflating: stanford-corenlp-full-2018-10-05/patterns/example.properties
#  extracting: stanford-corenlp-full-2018-10-05/patterns/otherpeople.txt
#  extracting: stanford-corenlp-full-2018-10-05/patterns/goldplaces.txt
#   inflating: stanford-corenlp-full-2018-10-05/patterns/stopwords.txt
#   inflating: stanford-corenlp-full-2018-10-05/patterns/presidents.txt
#   inflating: stanford-corenlp-full-2018-10-05/patterns/names.txt
#  extracting: stanford-corenlp-full-2018-10-05/patterns/places.txt
#   inflating: stanford-corenlp-full-2018-10-05/patterns/goldnames.txt
#   inflating: stanford-corenlp-full-2018-10-05/slf4j-simple.jar
#   inflating: stanford-corenlp-full-2018-10-05/stanford-corenlp-3.9.2-sources.jar
#   inflating: stanford-corenlp-full-2018-10-05/input.txt
#   inflating: stanford-corenlp-full-2018-10-05/joda-time.jar
#   inflating: stanford-corenlp-full-2018-10-05/xom.jar
#   inflating: stanford-corenlp-full-2018-10-05/jaxb-impl-2.4.0-b180830.0438-sources.jar
#   inflating: stanford-corenlp-full-2018-10-05/StanfordCoreNlpDemo.java
#   inflating: stanford-corenlp-full-2018-10-05/jaxb-core-2.3.0.1.jar
#   inflating: stanford-corenlp-full-2018-10-05/RESOURCE-LICENSES
#   inflating: stanford-corenlp-full-2018-10-05/javax.activation-api-1.2.0-sources.jar
#   inflating: stanford-corenlp-full-2018-10-05/slf4j-api.jar
#   inflating: stanford-corenlp-full-2018-10-05/pom-java-11.xml
#   inflating: stanford-corenlp-full-2018-10-05/ejml-0.23.jar
#   inflating: stanford-corenlp-full-2018-10-05/javax.json.jar
#   inflating: stanford-corenlp-full-2018-10-05/Makefile
#   inflating: stanford-corenlp-full-2018-10-05/corenlp.sh
#   inflating: stanford-corenlp-full-2018-10-05/joda-time-2.9-sources.jar
#   inflating: stanford-corenlp-full-2018-10-05/jaxb-api-2.4.0-b180830.0359.jar
#   inflating: stanford-corenlp-full-2018-10-05/jollyday.jar
#   inflating: stanford-corenlp-full-2018-10-05/ShiftReduceDemo.java
#   inflating: stanford-corenlp-full-2018-10-05/jaxb-impl-2.4.0-b180830.0438.jar
#   inflating: stanford-corenlp-full-2018-10-05/stanford-corenlp-3.9.2.jar
#   inflating: stanford-corenlp-full-2018-10-05/SemgrexDemo.java
#   inflating: stanford-corenlp-full-2018-10-05/LICENSE.txt

# %%
# !pip install ./KERMIT/kerMIT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./KERMIT/kerMIT
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from kerMIT==2.0) (1.21.6)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from kerMIT==2.0) (3.7)
# Requirement already satisfied: colormap in /usr/local/lib/python3.8/dist-packages (from kerMIT==2.0) (1.0.4)
# Requirement already satisfied: easydev in /usr/local/lib/python3.8/dist-packages (from kerMIT==2.0) (0.12.0)
# Requirement already satisfied: StanfordCoreNLP in /usr/local/lib/python3.8/dist-packages (from kerMIT==2.0) (3.9.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from kerMIT==2.0) (1.3.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from easydev->kerMIT==2.0) (4.8.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.8/dist-packages (from easydev->kerMIT==2.0) (0.4.6)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.8/dist-packages (from easydev->kerMIT==2.0) (6.7.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->kerMIT==2.0) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->kerMIT==2.0) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->kerMIT==2.0) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk->kerMIT==2.0) (4.64.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->kerMIT==2.0) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->kerMIT==2.0) (2.8.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from StanfordCoreNLP->kerMIT==2.0) (5.4.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from StanfordCoreNLP->kerMIT==2.0) (2.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->kerMIT==2.0) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->easydev->kerMIT==2.0) (0.7.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->StanfordCoreNLP->kerMIT==2.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->StanfordCoreNLP->kerMIT==2.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->StanfordCoreNLP->kerMIT==2.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->StanfordCoreNLP->kerMIT==2.0) (1.26.14)
# Building wheels for collected packages: kerMIT
#   Building wheel for kerMIT (setup.py) ... done
#   Created wheel for kerMIT: filename=kerMIT-2.0-py3-none-any.whl size=203692 sha256=d3027cedebf1ccda4c9441bcc888746e3b55055b9c7d1ec5c507b2110cba3762
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ky259qba/wheels/18/e2/cb/5e6f4899eaaf2bbe53003c96629d35d0909de8736544643098
# Successfully built kerMIT
# Installing collected packages: kerMIT
#   Attempting uninstall: kerMIT
#     Found existing installation: kerMIT 2.0
#     Uninstalling kerMIT-2.0:
#       Successfully uninstalled kerMIT-2.0
# Successfully installed kerMIT-2.0

# %% [markdown]
# Download pre-trained model weights on **generic** sentiment analysis task.
#
# You can replace weights by training KERMIT on your **custom** dataset by following **this guide**: *https://github.com/ART-Group-it/KERMIT_Tutorial*

# %%
#download weights from drive
from google.colab import drive

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1VV8mOpWTD3Nj2y7eMNGDAbAEBiSchdc0' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1VV8mOpWTD3Nj2y7eMNGDAbAEBiSchdc0" -O aria.pt && rm -rf /tmp/cookies.txt
# Out:
# --2023-01-18 14:26:56--  https://docs.google.com/uc?export=download&confirm=&id=1VV8mOpWTD3Nj2y7eMNGDAbAEBiSchdc0
# Resolving docs.google.com (docs.google.com)... 173.194.216.113, 173.194.216.138, 173.194.216.139, ...
# Connecting to docs.google.com (docs.google.com)|173.194.216.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/g42cj9udt9hrb0ika43c21rrsqqbhvcc/1674051975000/14762939017184396674/*/1VV8mOpWTD3Nj2y7eMNGDAbAEBiSchdc0?e=download&uuid=04fe2aa0-d198-43d1-a5f2-1e7a7a81fc28 [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-18 14:26:57--  https://doc-0s-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/g42cj9udt9hrb0ika43c21rrsqqbhvcc/1674051975000/14762939017184396674/*/1VV8mOpWTD3Nj2y7eMNGDAbAEBiSchdc0?e=download&uuid=04fe2aa0-d198-43d1-a5f2-1e7a7a81fc28
# Resolving doc-0s-8c-docs.googleusercontent.com (doc-0s-8c-docs.googleusercontent.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to doc-0s-8c-docs.googleusercontent.com (doc-0s-8c-docs.googleusercontent.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2183924 (2.1M) [application/octet-stream]
# Saving to: ‘aria.pt’
#
# aria.pt             100%[===================>]   2.08M  --.-KB/s    in 0.01s
#
# 2023-01-18 14:26:57 (171 MB/s) - ‘aria.pt’ saved [2183924/2183924]

# %%
#download weights from drive
from google.colab import drive

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1RMPEfoHZ_Jqyx2DSul2CO0NOEAwezbEx' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1RMPEfoHZ_Jqyx2DSul2CO0NOEAwezbEx" -O aria_second.pt && rm -rf /tmp/cookies.txt
# Out:
# --2023-01-18 14:26:59--  https://docs.google.com/uc?export=download&confirm=&id=1RMPEfoHZ_Jqyx2DSul2CO0NOEAwezbEx
# Resolving docs.google.com (docs.google.com)... 173.194.216.113, 173.194.216.138, 173.194.216.139, ...
# Connecting to docs.google.com (docs.google.com)|173.194.216.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0o-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3l3ec02j0f8eclu0uhb6jqfoj7tpmrl2/1674051975000/14762939017184396674/*/1RMPEfoHZ_Jqyx2DSul2CO0NOEAwezbEx?e=download&uuid=38f31c3d-c7c5-4f3f-88cf-0cefddc60779 [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-18 14:26:59--  https://doc-0o-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3l3ec02j0f8eclu0uhb6jqfoj7tpmrl2/1674051975000/14762939017184396674/*/1RMPEfoHZ_Jqyx2DSul2CO0NOEAwezbEx?e=download&uuid=38f31c3d-c7c5-4f3f-88cf-0cefddc60779
# Resolving doc-0o-8c-docs.googleusercontent.com (doc-0o-8c-docs.googleusercontent.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to doc-0o-8c-docs.googleusercontent.com (doc-0o-8c-docs.googleusercontent.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8199998 (7.8M) [application/octet-stream]
# Saving to: ‘aria_second.pt’
#
# aria_second.pt      100%[===================>]   7.82M  --.-KB/s    in 0.03s
#
# 2023-01-18 14:26:59 (263 MB/s) - ‘aria_second.pt’ saved [8199998/8199998]

# %%
import os
import sys
import transformers
import torch
from torch import nn
from torch import optim

#set manual seed for replicability
if torch.cuda.is_available(): torch.cuda.manual_seed_all(23)
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# Show few examples of dataset

# %% [markdown]
# Model definition and weights loading

# %%
from kerMIT.samples.models import DTBert


BERT_DIM = 0
TREE_DIM = 128
OUTPUT_DIM = 1


import torch.nn.functional as F

class FeedForward(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(FeedForward, self).__init__()
        self.linear_1 = nn.Linear(input_dim, 512)
        self.linear_3 = nn.Linear(512, output_dim)
        self.dropout = nn.Dropout(p=0.1)
        self.relu = nn.ReLU()

    def forward(self, x):
        out = self.linear_1(x)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.linear_3(out)
        final = F.log_softmax(out, dim=1)
        return final
      
model = FeedForward(4000, 2)
print(model)
model.cuda()

criterion = nn.NLLLoss()
learning_rate = 0.003
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
pathModel = 'shared_weights/1st_pattern.pt' #'\(VP VB[A-Z]? \(NP DT NN[A-Z]?[A-Z]?\)\)

model = torch.load(pathModel)


for name, param in model.named_parameters():
  print(name, param.data.shape)

for i in model.parameters():
  print(i.shape)
  #input()
# Out:
# FeedForward(
#   (linear_1): Linear(in_features=4000, out_features=512, bias=True)
#   (linear_3): Linear(in_features=512, out_features=2, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): ReLU()
# )
# linear_1.weight torch.Size([512, 4000])
# linear_1.bias torch.Size([512])
# linear_3.weight torch.Size([2, 512])
# linear_3.bias torch.Size([2])
# torch.Size([512, 4000])
# torch.Size([512])
# torch.Size([2, 512])
# torch.Size([2])

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## KERMIT applied to a single instance given in input

# %%
from kerMIT.dtk import DT
from kerMIT.operation import fast_shuffled_convolution
from kerMIT.explain import activationSubtreeLRP as act
from kerMIT.explain import modelToExplain as mte
from kerMIT.explain import kerMITviz 

#parser definition
calculator = DT(dimension=4000, LAMBDA=0.6, operation=fast_shuffled_convolution)

# %%
from kerMIT.tree_encode import parse as parse_tree
from kerMIT.samples import utils

from kerMIT import tree
from kerMIT.dtk import DT
from tqdm import tqdm
import re, torch, pickle, copy
from torchtext import data as datx
from torch import nn, optim
from keras_preprocessing.sequence import pad_sequences
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler


def get_sentence(sentence, calculator):
    # generate tree
    tree_sentence = parse_tree(sentence)
    tree_sentence = re.sub("\("," (",tree_sentence)
    tree_sentence = tree_sentence[1:]
    # encoding
    alberoCompleto = tree.Tree(string=tree_sentence)
    dtk_sentence = calculator.dt(alberoCompleto).reshape(1,4000)
    dtk_sentence = torch.from_numpy(dtk_sentence).float().cuda()
    return tree_sentence, dtk_sentence


#sentence in input

#sentence = "I know he could see a series." #pattern 1 '\(VP VB[A-Z]? \(NP DT NN[A-Z]?[A-Z]?\)\)'
#sentence = "it was nice going up there and see that scenery" #pattern 1 '\(VP VB[A-Z]? \(NP DT NN[A-Z]?[A-Z]?\)\)'


sentence = "The tourist supports the authors."

#sentence = "I think that the tourist supports the authors."
#sentence = "It expects the tree of the day"


#target value
target = 1 

index = 2

tree_sentence, dtk_sentence = get_sentence(sentence, calculator)

# %%
#show test trees 
#tree_sentence = "(S (@S (NP (NP (@NP (DT The) (NN wait)) (NN time)) (PP (IN for) (NP (@NP (DT a) (JJ green)) (NN card)))) (VP (AUX has) (VP (@VP (VBN risen) (PP (IN from) (NP (@NP (NP (CD 21) (NNS months)) (TO to)) (NP (CD 33) (NNS months))))) (PP (IN in) (NP (@NP (DT those) (JJ same)) (NNS regions)))))) (. .))"
#tree_sentence = "(S (VP (VB Reject) (NP (DT the) (NN topic))) (. .))"

# %%
tree_sentence
# Out:
# '(S     (NP  (DT The)  (NN tourist))     (VP  (VBZ supports)       (NP  (DT the)  (NNS authors)))     (. .))'

# %%
#### INIZIO DARIO

activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

def getWeightAnBiasByName(layer_name):
    weight, bias = _,_
    for name, param in model.named_parameters():
        if name == layer_name+'.weight' and param.requires_grad:
            weight = param.data
        elif name == layer_name+'.bias' and param.requires_grad:
            bias = param.data
    return weight, bias

def lrp_linear_torch(hin, w, b, hout, Rout, bias_nb_units, eps, bias_factor=0.0, debug=False):
    """
    LRP for a linear layer with input dim D and output dim M.
    Args:
    - hin:            forward pass input, of shape (D,)
    - w:              connection weights, of shape (D, M)
    - b:              biases, of shape (M,)
    - hout:           forward pass output, of shape (M,) (unequal to np.dot(w.T,hin)+b if more than one incoming layer!)
    - Rout:           relevance at layer output, of shape (M,)
    - bias_nb_units:  total number of connected lower-layer units (onto which the bias/stabilizer contribution is redistributed for sanity check)
    - eps:            stabilizer (small positive number)
    - bias_factor:    set to 1.0 to check global relevance conservation, otherwise use 0.0 to ignore bias/stabilizer redistribution (recommended)
    Returns:
    - Rin:            relevance at layer input, of shape (D,)
    """
    sign_out = torch.where(hout.cpu() >= 0 , torch.Tensor([1.]), torch.Tensor([-1.])).view(1,-1) # shape (1, M)
    
    numer    = (w * hin.view(-1,1)).cpu() + ( bias_factor * (b.view(1,-1)*1. + eps*sign_out*1.) / bias_nb_units ) # shape (D, M)
    # Note: here we multiply the bias_factor with both the bias b and the stabilizer eps since in fact
    # using the term (b[na,:]*1. + eps*sign_out*1.) / bias_nb_units in the numerator is only useful for sanity check
    # (in the initial paper version we were using (bias_factor*b[na,:]*1. + eps*sign_out*1.) / bias_nb_units instead)
    
    denom    = hout.view(1,-1) + (eps*sign_out*1.)   # shape (1, M)
    
    message  = (numer/denom) * Rout.view(1,-1)       # shape (D, M)
    
    Rin      = message.sum(axis=1)              # shape (D,)
    
    if debug:
        print("local diff: ", Rout.sum() - Rin.sum())
    # Note: 
    # - local  layer   relevance conservation if bias_factor==1.0 and bias_nb_units==D (i.e. when only one incoming layer)
    # - global network relevance conservation if bias_factor==1.0 and bias_nb_units set accordingly to the total number of lower-layer connections 
    # -> can be used for sanity check
    
    return Rin

def prepare_single_pass(activation, start_layer, end_layer, isFirstCompute=True):
    hout = activation[start_layer].reshape(-1)
    if end_layer != None:
        hin = activation[end_layer].reshape(-1).cpu()
    else:
        hin = None

    w, b = getWeightAnBiasByName(start_layer)
    w = w.reshape(w.shape[1],w.shape[0])
    
    bias_nb_units = b.shape[0]
    eps = 0.001
    #eps = 0.2
    bias_factor = 1.0
    if isFirstCompute:
        mask = torch.zeros( hout.shape[0] )
        mask[ torch.argmax(hout) ] = hout[ torch.argmax(hout) ]
        Rout = torch.Tensor(mask).cpu()
    else:
        Rout = None
    return hin, w.cpu(), b.cpu(), hout.cpu(), Rout, bias_nb_units, eps, bias_factor

##### FMZ Trying an intuition 
def compute_LRP_FFNN(activation, layer_names, on_demand_embedding_matrix, single_test):
    isFirstCompute = True
    for i in range(len(layer_names)-1):
        print(layer_names[i], layer_names[i+1])
        hin, w, b, hout, Rout, bias_nb_units, eps, bias_factor = prepare_single_pass(activation, layer_names[i], layer_names[i+1], isFirstCompute)
        if not isFirstCompute:
            Rout = Rin
        Rin = lrp_linear_torch(hin, w, b, hout, Rout, bias_nb_units, eps, bias_factor)
        isFirstCompute = False
    # compute the last layer
    _, w, b, hout, _, bias_nb_units, eps, bias_factor = prepare_single_pass(activation, layer_names[-1], None, False)
    Rout = Rin
    hin = single_test.reshape(-1).cpu()
    #print(on_demand_embedding_matrix.shape)
    #print(w.shape)
    Rin = lrp_linear_torch(hin, torch.matmul(on_demand_embedding_matrix,w), b, hout, Rout, bias_nb_units, eps, bias_factor, debug=False)
    return Rin

#### FINE DARIO

# %%
# resister forward hook for activation 
model.linear_1.register_forward_hook(get_activation('linear_1'))
#model.linear_2.register_forward_hook(get_activation('linear_2'))
model.linear_3.register_forward_hook(get_activation('linear_3'))

#layer_names = ['linear_3','linear_2','linear_1']
layer_names = ['linear_3','linear_1']

print(layer_names)
# Out:
# ['linear_3', 'linear_1']

# %%
# resister forward hook for activation 
model.linear_1.register_forward_hook(get_activation('linear_1'))
#model.linear_2.register_forward_hook(get_activation('linear_2'))
model.linear_3.register_forward_hook(get_activation('linear_3'))

# %%
#relevance = compute_LRP_FFNN(activation, layer_names, dtk_sentence)
#relevance, relevance.shape

# %%
from kerMIT.explain.modelToExplain import lrp_DT,relevance_to_string
from kerMIT.explain.activationSubtreeLRP import ActivationSubtreeLRP

# %%
from kerMIT import tree
import torch

# calculate prediction
#tree_sentence ="(S (NP  (PRP it)) (VP  (VBD was) (ADJP  (JJ nice) (S (VP (VP  (VBG going) (ADVP  (RB up)  (RB there))) (CC and) (VP  (VB see) (NP  (DT that) (NN scenery))))))))"
###tree_sentence = "(S     (NP  (DT The)  (NN tourist))     (XX  (VBZ supports)       (NP  (DT the)  (NNS authors)))     (. .))"

from kerMIT import tree
import torch

tree_sentence_tree = tree.Tree(string=tree_sentence)
dtk_sentence = calculator.dt(tree_sentence_tree).reshape(1,4000)
dtk_sentence = torch.from_numpy(dtk_sentence).float().cuda()

# prediction
output = model(dtk_sentence)
#output
torch.exp(output)
# Out:
# tensor([[3.7838e-06, 1.0000e+00]], device='cuda:0', grad_fn=<ExpBackward0>)

# %% [markdown]
# Given the tree t, this block computes its dtfs, the input vector of the subtrees, and the LRP activations.

# %%
import numpy as np


tree_sentence_tree = tree.Tree(string=tree_sentence)
act_lrp = ActivationSubtreeLRP(calculator)

_, tree_index_dict, on_demand_embedding_matrix, tree_index_dict_inverse, activation_vector = act_lrp.on_demand_embedding_matrix(tree_sentence_tree)
#print(activation_vector)
#print(on_demand_embedding_matrix)
on_demand_embedding_matrix = torch.Tensor(on_demand_embedding_matrix)
activation_vector = torch.Tensor(activation_vector)
relevance = compute_LRP_FFNN(activation, layer_names, on_demand_embedding_matrix, activation_vector)




# Generate Cache of dtfs

#act_lrp.calculateDTFs(tree_sentence_tree) 
#_, tree_index_dict, on_demand_embedding_matrix, tree_index_dict_inverse = act_lrp.relevance_matrix()
#tree_sentecne_tree = tree.Tree(string=tree_sentence)
#dim = len(tree_index_dict.keys())
#activation_vector = []
#for c in range(0,dim):
  #print(tree_index_dict_inverse[c].allNodes())
  #t_size = len(tree_index_dict_inverse[c])
#  t_size = 0 
#  for n in tree_index_dict_inverse[c].allNodes():
#    if not n.isTerminal(): 
#      t_size += 1   
#  activation_vector.append(np.sqrt(calculator.LAMBDA**t_size))
#activation_vector = torch.Tensor(activation_vector)


#act_tree_lrp = act_lrp.activation(relevance, tree_sentence)
#act_tree_lrp
#print(on_demand_embedding_matrix)
print(tree_index_dict)
#print(activation)
act_tree_lrp = act_lrp.saveActivation(tree_sentence_tree,relevance,tree_index_dict)
act_tree_lrp

active_subtrees = sorted(act_tree_lrp['act_sub_trees'], key=lambda x:x[1], reverse=True) 

#stampare 
#for t in active_subtrees:
#  print(t)
# Out:
# linear_3 linear_1
# {(DT The): 0, (NN tourist): 1, (NP (DT The) (NN tourist)): 2, (NP DT (NN tourist)): 3, (NP (DT The) NN): 4, (NP DT NN): 5, (VBZ supports): 6, (DT the): 7, (NNS authors): 8, (NP (DT the) (NNS authors)): 9, (NP DT (NNS authors)): 10, (NP (DT the) NNS): 11, (NP DT NNS): 12, (VP (VBZ supports) (NP (DT the) (NNS authors))): 13, (VP VBZ (NP (DT the) (NNS authors))): 14, (VP (VBZ supports) (NP DT (NNS authors))): 15, (VP VBZ (NP DT (NNS authors))): 16, (VP (VBZ supports) (NP (DT the) NNS)): 17, (VP VBZ (NP (DT the) NNS)): 18, (VP (VBZ supports) (NP DT NNS)): 19, (VP VBZ (NP DT NNS)): 20, (VP (VBZ supports) NP): 21, (VP VBZ NP): 22, (. .): 23, (S (NP (DT The) (NN tourist)) (VP (VBZ supports) (NP (DT the) (NNS authors))) (. .)): 24, (S (NP DT (NN tourist)) (VP (VBZ supports) (NP (DT the) (NNS authors))) (. .)): 25, (S (NP (DT The) NN) (VP (VBZ supports) (NP (DT the) (NNS authors))) (. .)): 26, (S (NP DT NN) (VP (VBZ supports) (NP (DT the) (NNS authors))) (. .)): 27, (S NP (VP (VBZ supports) (NP (DT the) (NNS authors))) (. .)): 28, (S (NP (DT The) (NN tourist)) (VP VBZ (NP (DT the) (NNS authors))) (. .)): 29, (S (NP DT (NN tourist)) (VP VBZ (NP (DT the) (NNS authors))) (. .)): 30, (S (NP (DT The) NN) (VP VBZ (NP (DT the) (NNS authors))) (. .)): 31, (S (NP DT NN) (VP VBZ (NP (DT the) (NNS authors))) (. .)): 32, (S NP (VP VBZ (NP (DT the) (NNS authors))) (. .)): 33, (S (NP (DT The) (NN tourist)) (VP (VBZ supports) (NP DT (NNS authors))) (. .)): 34, (S (NP DT (NN tourist)) (VP (VBZ supports) (NP DT (NNS authors))) (. .)): 35, (S (NP (DT The) NN) (VP (VBZ supports) (NP DT (NNS authors))) (. .)): 36, (S (NP DT NN) (VP (VBZ supports) (NP DT (NNS authors))) (. .)): 37, (S NP (VP (VBZ supports) (NP DT (NNS authors))) (. .)): 38, (S (NP (DT The) (NN tourist)) (VP VBZ (NP DT (NNS authors))) (. .)): 39, (S (NP DT (NN tourist)) (VP VBZ (NP DT (NNS authors))) (. .)): 40, (S (NP (DT The) NN) (VP VBZ (NP DT (NNS authors))) (. .)): 41, (S (NP DT NN) (VP VBZ (NP DT (NNS authors))) (. .)): 42, (S NP (VP VBZ (NP DT (NNS authors))) (. .)): 43, (S (NP (DT The) (NN tourist)) (VP (VBZ supports) (NP (DT the) NNS)) (. .)): 44, (S (NP DT (NN tourist)) (VP (VBZ supports) (NP (DT the) NNS)) (. .)): 45, (S (NP (DT The) NN) (VP (VBZ supports) (NP (DT the) NNS)) (. .)): 46, (S (NP DT NN) (VP (VBZ supports) (NP (DT the) NNS)) (. .)): 47, (S NP (VP (VBZ supports) (NP (DT the) NNS)) (. .)): 48, (S (NP (DT The) (NN tourist)) (VP VBZ (NP (DT the) NNS)) (. .)): 49, (S (NP DT (NN tourist)) (VP VBZ (NP (DT the) NNS)) (. .)): 50, (S (NP (DT The) NN) (VP VBZ (NP (DT the) NNS)) (. .)): 51, (S (NP DT NN) (VP VBZ (NP (DT the) NNS)) (. .)): 52, (S NP (VP VBZ (NP (DT the) NNS)) (. .)): 53, (S (NP (DT The) (NN tourist)) (VP (VBZ supports) (NP DT NNS)) (. .)): 54, (S (NP DT (NN tourist)) (VP (VBZ supports) (NP DT NNS)) (. .)): 55, (S (NP (DT The) NN) (VP (VBZ supports) (NP DT NNS)) (. .)): 56, (S (NP DT NN) (VP (VBZ supports) (NP DT NNS)) (. .)): 57, (S NP (VP (VBZ supports) (NP DT NNS)) (. .)): 58, (S (NP (DT The) (NN tourist)) (VP VBZ (NP DT NNS)) (. .)): 59, (S (NP DT (NN tourist)) (VP VBZ (NP DT NNS)) (. .)): 60, (S (NP (DT The) NN) (VP VBZ (NP DT NNS)) (. .)): 61, (S (NP DT NN) (VP VBZ (NP DT NNS)) (. .)): 62, (S NP (VP VBZ (NP DT NNS)) (. .)): 63, (S (NP (DT The) (NN tourist)) (VP (VBZ supports) NP) (. .)): 64, (S (NP DT (NN tourist)) (VP (VBZ supports) NP) (. .)): 65, (S (NP (DT The) NN) (VP (VBZ supports) NP) (. .)): 66, (S (NP DT NN) (VP (VBZ supports) NP) (. .)): 67, (S NP (VP (VBZ supports) NP) (. .)): 68, (S (NP (DT The) (NN tourist)) (VP VBZ NP) (. .)): 69, (S (NP DT (NN tourist)) (VP VBZ NP) (. .)): 70, (S (NP (DT The) NN) (VP VBZ NP) (. .)): 71, (S (NP DT NN) (VP VBZ NP) (. .)): 72, (S NP (VP VBZ NP) (. .)): 73, (S (NP (DT The) (NN tourist)) VP (. .)): 74, (S (NP DT (NN tourist)) VP (. .)): 75, (S (NP (DT The) NN) VP (. .)): 76, (S (NP DT NN) VP (. .)): 77, (S NP VP (. .)): 78, (S (NP (DT The) (NN tourist)) (VP (VBZ supports) (NP (DT the) (NNS authors))) .): 79, (S (NP ...

# %% [markdown]
# Here, there is the proof that the sum of dtfs of t is equal to the dtk of t.

# %%
import re
pattern_re = r'\(VP VB[A-Z]? \(NP DT NN[A-Z]?[A-Z]?\)\)'
for count,el in enumerate(active_subtrees):
  # print(el[1])
  # if "(VP VBP (VP VBG PP))" == str(el[0]):# and "VB" in str(el[0]):# and "they" in el[0]:
  if re.fullmatch(pattern_re, str(el[0])):
    print(f"rank : {count}","*****",el[0],el[1],"*****")
print(f"total number of subtrees {len(active_subtrees)}")
# Out:
# rank : 2 ***** (VP VBZ (NP DT NNS)) [3.9100227] *****
# total number of subtrees 134

# %%
dtk1_sentence = torch.matmul(on_demand_embedding_matrix.T,activation_vector)
print(dtk1_sentence)
print(dtk_sentence)
# Out:
# tensor([ 0.0535, -0.0126, -0.0565,  ..., -0.0518,  0.0606,  0.0378])
# tensor([[ 0.0535, -0.0126, -0.0565,  ..., -0.0518,  0.0606,  0.0378]],
#        device='cuda:0')

# %%
#visualization of previously extracted activations through heat parse tree
heat_parse_tree = kerMITviz.assign_contribution_nodes(act_tree_lrp)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 202.97it/s]

# %%
heat_parse_tree
# Out:
# [{'ACT_0': '(S::0.14813246 (NP::0.25282833 (DT::0.25282833 The:0.055498783) (NN::1.0 tourist:1.0)) (VP::0.36805698 (VBZ::0.7803657 supports:0.7803657) (NP::0.36805698 (DT::0.36805698 the:0.21247752) (NNS::0.36805698 authors:0.0))) (.::0.1492632 .:0.1492632))'}]

# %%
import IPython
import fileinput

# %%
brotherDistance = "5"
levelLength = "50"
#brotherDistance = input('Enter brother Distance in px (recommended 5): ')
#levelLength = input('Enter level Lenght in px (recommended 50: ')

# %%
string = str(heat_parse_tree)
brotherDistance
levelLength
 
name = "var string"
name1 = "var brotherDistance"
name2 = "var levelLength"

# !cp '/content/KERMIT/Visualizer/notebook/index.html' '/content/KERMIT/Visualizer/notebook/index_New.html'
# !cp '/content/KERMIT/Visualizer/notebook/index2.html' '/content/KERMIT/Visualizer/notebook/index2_New.html'

 
with open('/content/KERMIT/Visualizer/notebook/index_New.html','r') as names_file:
    content = names_file.read()
    new = content.replace(name, '='.join([name, '"' + string + '"']))
    new = new.replace(name1, '='.join([name1, brotherDistance]))
    new = new.replace(name2, '='.join([name2, levelLength]))
 
with open('/content/KERMIT/Visualizer/notebook/index_New.html','w') as new_names_file:
    new_names_file.write(new)
 

with open('/content/KERMIT/Visualizer/notebook/index2_New.html','r') as names_file:
    content = names_file.read()
    new = content.replace(name, '='.join([name, '"' + string + '"']))
    new = new.replace(name1, '='.join([name1, brotherDistance]))
    new = new.replace(name2, '='.join([name2, levelLength]))
 
with open('/content/KERMIT/Visualizer/notebook/index2_New.html','w') as new_names_file:
    new_names_file.write(new)

# %%
#Version 1
IPython.display.HTML(filename='/content/KERMIT/Visualizer/notebook/index_New.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#     <title>KERMIT-viz</title>
#
#     <style>
#         * {
#             box-sizing: border-box;
#         }
#
#
#         input[type=text],
#         select,
#         textarea {
#             width: 100%;
#             padding: 12px;
#             border: 1px solid #ccc;
#             border-radius: 4px;
#             resize: vertical;
#         }
#
#         label {
#             padding: 12px 12px 12px 0;
#             display: inline-block;
#         }
#
#         input[type=submit] {
#             background-color: #4CAF50;
#             color: white;
#             padding: 12px 20px;
#             border: none;
#             border-radius: 4px;
#             cursor: pointer;
#             float: right;
#         }
#
#         input[type=number] {
#             width: 25%;
#             margin-top: 10px;
#             border-radius: 4px;
#             border: 1px solid #ccc;
#             padding: 12px;
#             resize: vertical;
#         }
#
#         input[type=submit]:hover {
#             background-color: #45a049;
#         }
#
#         .container {
#             border-radius: 5px;
#             padding: 20px;
#             background-color: darkseagreen;
#         }
#
#         .col-25 {
#             float: left;
#             width: 25%;
#             margin-top: 6px;
#             text-align: center;
#         }
#
#         .col-75 {
#             width: 75%;
#             margin-top: 6px;
#             float: left;
#         }
#
#         /* Clear floats after the columns */
#         .row:after {
#             content: "";
#             display: table;
#             clear: both;
#         }
#
#
#         /* Responsive layout - when the screen is less than 600px wide, make the two columns stack on top of each other instead of next to each other */
#         @media screen and (max-width: 600px) {
#
#             .col-25,
#             .col-75,
#             input[type=submit] {
#                 width: 100%;
#                 margin-top: 0;
#             }
#
#             p {
#                 text-align: center;
#             }
#         }
#
#         h1 {
#             text-align: center;
#         }
#
#         button {
#             background-color: #4CAF50;
#             color: white;
#             padding: 12px 20px;
#             border: none;
#             border-radius: 4px;
#             cursor: pointer;
#         }
#
#         button:hover {
#             background-color: #45a049;
#         }
#
#
#         p {
#             clear: both;
#         }
#
#         ul {
#             padding: 15px;
#             margin: 10px;
#         }
#
#         ul li {
#             margin-top: 5px;
#         }
#
#         footer {
#             margin-top: 40px;
#         }
#     </style>
#
# </head>
#
# <body>
#     <h1>Smart visualization of Heat Parse Trees for KERMIT</h1>
#
#     <div>
#         <canvas id="myCanvas" width="100%" height="100%" style="border:1px solid #000000;">
#         </canvas>
#     </div>
#     <p>
#         <button type="button" id="myBtn" onclick="downloadCanvas()">Download Image</button>
#     </p>
#     <footer>
#          © ART Group, Università degli Studi di Roma "Tor Vergata", code avaiable on <a href="https://github.com/ART-Group-it/KERMIT" target="blank"> <i
#                 class="fa fa-github" aria-hidden="true"></i></a>
#     </footer>
# </body>
#
# </html>
#
#
#
# <script>
# var string="[{'ACT_0': '(S::0.14813246 (NP::0.25282833 (DT::0.25282833 The:0.055498783) (NN::1.0 tourist:1.0)) (VP::0.36805698 (VBZ::0.7803657 supports:0.7803657) (NP::0.36805698 (DT::0.36805698 the:0.21247752) (NNS::0.36805698 authors:0.0))) (.::0.1492632 .:0.1492632))'}]"
# var brotherDistance=5
# var levelLength=50
#
# var result = []; //is the data structure final
#
#     //Start to divide the parse tree and put into a data structure
#     var res = string.slice(string.indexOf('('), string.lastIndexOf("'"));
#     var pilaParent = [];
#     var firstIndex = res.indexOf(':');
#     var j = 0;
#     for (i = 0; i <= res.length; i++) {
#
#         if (res[i] == '(') {
#             var nome = computeName(i);
#             i = i + nome.length;
#             var valore = computeValue(i + 1);
#             i = i + valore.length;
#
#             if (j == 0) {
#                 result[j] = {
#                     name: nome,
#                     value: valore,
#                     parent: {},
#                     id: j,
#                     disegnato: false
#                 }
#                 pilaParent.push(result[j]);
#             } else {
#                 result[j] = {
#                     name: nome,
#                     value: valore,
#                     parent: {
#                         padre: pilaParent[pilaParent.length - 1]
#                     },
#                     id: j,
#                     disegnato: false
#                 }
#                 pilaParent.push(result[j]);
#             }
#             j++;
#         }
#
#
#         if (res[i] == ' ' && res[i + 1] != '(') {
#             var nome = computeName(i);
#             i = i + nome.length;
#             var valore = computeValue(i + 1);
#             i = i + valore.length;
#
#             result[j] = {
#                 name: nome,
#                 value: valore,
#                 parent: {
#                     padre: pilaParent[pilaParent.length - 1]
#                 },
#                 id: j,
#                 disegnato: false
#             }
#             j++;
#         }
#
#         if (res[i] == ')') {
#             pilaParent.pop();
#         }
#     }
#
#
#     for (i = 0; i < result.length; i++) {
#         var nodo = result[i].id;
#         var figli = [];
#         for (j = i; j < result.length; j++) {
#             if (j == 0) {
#                 j++;
#             }
#             if (nodo == result[j].parent.padre.id) {
#                 figli.push(result[j]);
#             }
#         }
#         result[i].children = figli;
#     }
#
#     function computeName(index) {  //function that computes the name of each node
#         var primaDuePunti = res.indexOf(":", index)
#
#         if (res[primaDuePunti + 1] == res[primaDuePunti]) {
#             return res.slice(index + 1, primaDuePunti + 1);
#         } else {
#             return res.slice(index + 1, primaDuePunti);
#         }
#     }
#
#     function computeValue(index) { //function that computes the value of each node
#         var inizioNumeri = index + 1;
#         var number = '';
#         while ((res[inizioNumeri] != ' ') && (res[inizioNumeri] != ')') && (inizioNumeri < res.length)) {
#             number = number + res[inizioNumeri];
#             inizioNumeri++;
#         }
#         if (isNaN(number)) {
#             var ultimiDuePunti = number.lastIndexOf(":") + 1;
#             number = number.slice(ultimiDuePunti);
#         }
#         return number;
#     }
#
#
#     var livello = 0;
#
#     function calcolaAltezza(dataStructure, level) {  //function that computes the height of the tree
#
#         var numChild = dataStructure.children.length;
#         dataStructure.livello = level;
#         if (numChild == 0) {
#             return;
#         }
#         for (let i = 0; i < dataStructure.children.length; i++) {
#             calcolaAltezza(dataStructure.children[i], level + 1)
#         }
#         level = level + 1;
#         if (level > livello) {
#             livello = level;
#         }
#     }
#     calcolaAltezza(result[0], 1)
#
#
#
#     var arraySpazioLivelli = [];
#     for (let i = 0; i < livello; i++) {
#         arraySpazioLivelli[i] = 0;
#     }
#     var spazioOccupato = 0;
#
#     //initialize the canvas
#     var canvas = document.getElementById('myCanvas');
#     canvas.height = levelLength * (livello + 1);
#     canvas.width = window.innerWidth;
#
#
#     //function that take in input the datastructure resulting from the parse tree and the level and draws the entire Tree
#     function drawTree(dataStructure, level) {
#         var daDisegnare = true;
#         var numChild = dataStructure.children.length;
#
#         for (let i = 0; i < numChild; i++) {
#             drawTree(dataStructure.children[i], level + 1);
#         }
#
#         if (numChild == 0) { //base case
#             var spazioNodo

# %%
IPython.display.HTML(filename='/content/KERMIT/Visualizer/notebook/index2_New.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#     <title>KERMIT-viz</title>
#
#     <style>
#         * {
#             box-sizing: border-box;
#         }
#
#
#         input[type=text],
#         select,
#         textarea {
#             width: 100%;
#             padding: 12px;
#             border: 1px solid #ccc;
#             border-radius: 4px;
#             resize: vertical;
#         }
#
#         label {
#             padding: 12px 12px 12px 0;
#             display: inline-block;
#         }
#
#         input[type=submit] {
#             background-color: #4CAF50;
#             color: white;
#             padding: 12px 20px;
#             border: none;
#             border-radius: 4px;
#             cursor: pointer;
#             float: right;
#         }
#
#         input[type=number] {
#             width: 25%;
#             margin-top: 10px;
#             border-radius: 4px;
#             border: 1px solid #ccc;
#             padding: 12px;
#             resize: vertical;
#         }
#
#         input[type=submit]:hover {
#             background-color: #45a049;
#         }
#
#         .container {
#             border-radius: 5px;
#             padding: 20px;
#             background-color: darkseagreen;
#         }
#
#         .col-25 {
#             float: left;
#             width: 25%;
#             margin-top: 6px;
#             text-align: center;
#         }
#
#         .col-75 {
#             width: 75%;
#             margin-top: 6px;
#             float: left;
#         }
#
#         /* Clear floats after the columns */
#         .row:after {
#             content: "";
#             display: table;
#             clear: both;
#         }
#
#
#         /* Responsive layout - when the screen is less than 600px wide, make the two columns stack on top of each other instead of next to each other */
#         @media screen and (max-width: 600px) {
#
#             .col-25,
#             .col-75,
#             input[type=submit] {
#                 width: 100%;
#                 margin-top: 0;
#             }
#
#             p {
#                 text-align: center;
#             }
#         }
#
#         h1 {
#             text-align: center;
#         }
#
#         button {
#             background-color: #4CAF50;
#             color: white;
#             padding: 12px 20px;
#             border: none;
#             border-radius: 4px;
#             cursor: pointer;
#         }
#
#         button:hover {
#             background-color: #45a049;
#         }
#
#
#         p {
#             clear: both;
#         }
#
#         ul {
#             padding: 15px;
#             margin: 10px;
#         }
#
#         ul li {
#             margin-top: 5px;
#         }
#
#         footer {
#             margin-top: 40px;
#         }
#     </style>
#
# </head>
#
# <body>
#     <h1>Smart visualization of Heat Parse Trees for KERMIT</h1>
#
#     <div>
#         <canvas id="myCanvas" width="100%" height="100%" style="border:1px solid #000000;">
#         </canvas>
#     </div>
#     <p>
#         <button type="button" id="myBtn" onclick="downloadCanvas()">Download Image</button>
#     </p>
#     <footer>
#          © ART Group, Università degli Studi di Roma "Tor Vergata", code avaiable on <a href="https://github.com/ART-Group-it/KERMIT" target="blank"> <i
#                 class="fa fa-github" aria-hidden="true"></i></a>
#     </footer>
# </body>
#
# </html>
#
#
#
# <script>
# var string="[{'ACT_0': '(S::0.14813246 (NP::0.25282833 (DT::0.25282833 The:0.055498783) (NN::1.0 tourist:1.0)) (VP::0.36805698 (VBZ::0.7803657 supports:0.7803657) (NP::0.36805698 (DT::0.36805698 the:0.21247752) (NNS::0.36805698 authors:0.0))) (.::0.1492632 .:0.1492632))'}]"
# var brotherDistance=5
# var levelLength=50
#
# var result = [];
#
# var res = string.slice(string.indexOf('('), string.lastIndexOf("'"));
# var pilaParent = [];
# var firstIndex = res.indexOf(':');
# var j = 0;
# for (i = 0; i <= res.length; i++) {
#
#     if (res[i] == '(') {
#         var nome = computeName(i);
#         i = i + nome.length;
#         var valore = computeValue(i + 1);
#         i = i + valore.length;
#
#         if (j == 0) {
#             result[j] = {
#                 name: nome,
#                 value: valore,
#                 parent: {},
#                 id: j,
#                 disegnato: false
#             }
#             pilaParent.push(result[j]);
#         } else {
#             result[j] = {
#                 name: nome,
#                 value: valore,
#                 parent: {
#                     padre: pilaParent[pilaParent.length - 1]
#                 },
#                 id: j,
#                 disegnato: false
#             }
#             pilaParent.push(result[j]);
#         }
#         j++;
#     }
#
#
#     if (res[i] == ' ' && res[i + 1] != '(') {
#         var nome = computeName(i);
#         i = i + nome.length;
#         var valore = computeValue(i + 1);
#         i = i + valore.length;
#
#         result[j] = {
#             name: nome,
#             value: valore,
#             parent: {
#                 padre: pilaParent[pilaParent.length - 1]
#             },
#             id: j,
#             disegnato: false
#         }
#         j++;
#     }
#
#     if (res[i] == ')') {
#         pilaParent.pop();
#     }
# }
#
#
# for (i = 0; i < result.length; i++) {
#     var nodo = result[i].id;
#     var figli = [];
#     for (j = i; j < result.length; j++) {
#         if (j == 0) {
#             j++;
#         }
#         if (nodo == result[j].parent.padre.id) {
#             figli.push(result[j]);
#         }
#     }
#     result[i].children = figli;
# }
#
# function computeName(index) {
#     var primaDuePunti = res.indexOf(":", index)
#
#     if (res[primaDuePunti + 1] == res[primaDuePunti]) {
#         return res.slice(index + 1, primaDuePunti + 1);
#     } else {
#         return res.slice(index + 1, primaDuePunti);
#     }
# }
#
# function computeValue(index) {
#     var inizioNumeri = index + 1;
#     var number = '';
#     while ((res[inizioNumeri] != ' ') && (res[inizioNumeri] != ')') && (inizioNumeri < res.length)) {
#         number = number + res[inizioNumeri];
#         inizioNumeri++;
#     }
#     if (isNaN(number)) {
#         var ultimiDuePunti = number.lastIndexOf(":") + 1;
#         number = number.slice(ultimiDuePunti);
#     }
#     return number;
# }
#
#
# var livello = 0;
#
# function calcolaAltezza(dataStructure, level) {
#
#     var numChild = dataStructure.children.length;
#     dataStructure.livello = level;
#     if (numChild == 0) {
#         return;
#     }
#     for (let i = 0; i < dataStructure.children.length; i++) {
#         calcolaAltezza(dataStructure.children[i], level + 1)
#     }
#     level = level + 1;
#     if (level > livello) {
#         livello = level;
#     }
# }
# calcolaAltezza(result[0], 1)
#
#
# var canvas = document.getElementById('myCanvas');
# canvas.height = levelLength * (livello + 1)
# canvas.width = window.innerWidth;
#
#
# var spazioOccupato = 0;
#
# function drawTree(dataStructure, level) {
#     var daDisegnare = true;
#     var numChild = dataStructure.children.length;
#
#     for (let i = 0; i < numChild; i++) {
#         drawTree(dataStructure.children[i], level + 1);
#     }
#
#     if (numChild == 0) { //base case
#         var spazioNodo = dataStructure.name.length * (4.3 + (parseFloat(dataStructure.value) * 10))
#         drawNode(dataStructure, spazioOccupato, level * levelLength);
#         spazioOccupato += spazioNodo + brotherDistance;
#         daDisegnare = false;
#     }
#
#     for (let i = 0; i < dataStructure.children.length; i++) {
#         if (dataStructure.children[i].disegnato == false) {
#             daDisegnare = false;
#         }
#     }
#
#     if (daDisegnare == true) {
#         if (dataStructure.children.length == 1) {
#             var spazioNodo = dataStructure.name.length * (4.3 + (parseFloat(dataStructure.value) * 10))
#             var spazioNodoFiglio = dataStructure.children[0].name.length * (4.3 + (parseFloat(dataStructure.value) * 10))
#             drawNode(dataStructure, dataStructure.children[0].x, level * levelLength)
#             if (spazioOccupato < (spazioOccupato - spazioNodoFiglio + spazioNodo)) {
#                 spazioOccupato = (spazioOccupato - spazioNodoFiglio + spazioNo
